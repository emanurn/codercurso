# %%
pip install pandas

# %% [markdown]
# #Exercicio 1

# %%
import pandas as pd

abrir = pd.read_excel("best-selling game consoles.xlsx",
                       sheet_name="consoles")

abrir.head()
# Out:
#       Console Name      Type   Company  Released Year  Discontinuation Year  \
# 0    PlayStation 2      Home      Sony           2000                  2013
# 1      Nintendo DS  Handheld  Nintendo           2004                  2013
# 2  Nintendo Switch    Hybrid  Nintendo           2017                     0
# 3         Game Boy  Handheld  Nintendo           1989                  2003
# 4   Game Boy Color  Handheld  Nintendo           1998                  2003
#
#    Units sold (million)                                            Remarks
# 0                155.00           Final sales are greater than 155 million
# 1                154.02                                                NaN
# 2                122.55                                                NaN
# 3                 64.42  The Game Boy (1989) and the Game Boy Color (19...
# 4                 44.06                                                NaN

# %% [markdown]
# #Exercicio 2 e 3

# %%
abrir['Console Name'] = abrir['Console Name'].str.replace("NES", "Nitendinho").str.upper()

filtro=abrir['Released Year'] > 2010
df_filtrado = abrir[filtro]
print(df_filtrado)
# Out:
#                         Console Name       Type    Company  Released Year  \
# 2                    NINTENDO SWITCH     Hybrid   Nintendo           2017
# 5                      PLAYSTATION 4       Home       Sony           2013
# 12                      NINTENDO 3DS   Handheld   Nintendo           2011
# 14                          XBOX ONE       Home  Microsoft           2013
# 19                     PLAYSTATION 5       Home       Sony           2020
# 23                   XBOX SERIES X/S       Home  Microsoft           2020
# 24                             WII U       Home   Nintendo           2012
# 25                  PLAYSTATION VITA   Handheld       Sony           2011
# 33  SUPER NITENDINHO CLASSIC EDITION  Dedicated   Nintendo           2017
# 35        NITENDINHO CLASSIC EDITION  Dedicated   Nintendo           2016
#
#     Discontinuation Year  Units sold (million)  \
# 2                      0                122.55
# 5                      0                117.20
# ...

# %% [markdown]
# #Exercicio 4

# %%
abrir = abrir.fillna('Missing')

# %%
abrir
# Out:
#                          Console Name                 Type  \
# 0                       PLAYSTATION 2                 Home
# 1                         NINTENDO DS             Handheld
# 2                     NINTENDO SWITCH               Hybrid
# 3                            GAME BOY             Handheld
# 4                      GAME BOY COLOR             Handheld
# 5                       PLAYSTATION 4                 Home
# 6                         PLAYSTATION                 Home
# 7                                 WII                 Home
# 8                       PLAYSTATION 3                 Home
# 9                            XBOX 360                 Home
# 10                   GAME BOY ADVANCE             Handheld
# 11               PLAYSTATION PORTABLE             Handheld
# 12                       NINTENDO 3DS             Handheld
# 13                 NITENDINHO/FAMICOM                 Home
# 14                           XBOX ONE                 Home
# ...

# %% [markdown]
# #Exercicio 5

# %%
descontinuado= abrir[(abrir['Discontinuation Year'] - abrir['Released Year'] < 2)]
descontinuado
# Out:
#                         Console Name       Type           Company  \
# 2                    NINTENDO SWITCH     Hybrid          Nintendo
# 5                      PLAYSTATION 4       Home              Sony
# 19                     PLAYSTATION 5       Home              Sony
# 23                   XBOX SERIES X/S       Home         Microsoft
# 33  SUPER NITENDINHO CLASSIC EDITION  Dedicated          Nintendo
# 44                  MAGNAVOX ODYSSEY       Home  Magnavox/Philips
#
#     Released Year  Discontinuation Year  Units sold (million)  \
# 2            2017                     0                122.55
# 5            2013                     0                117.20
# 19           2020                     0                 30.00
# 23           2020                     0                 18.50
# 33           2017                  2018                  5.28
# 44           1978                  1975                  2.00
#
#                               Remarks
# ...
